# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задачи" data-toc-modified-id="Задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задачи</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Исследовательский-анализ-данных-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#изучим-средние-значения-и-стандартные-отклонения" data-toc-modified-id="изучим-средние-значения-и-стандартные-отклонения-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>изучим средние значения и стандартные отклонения</a></span></li><li><span><a href="#Сравним-2-группы,-те-кто-ушли-в-отток-и-кто-остался" data-toc-modified-id="Сравним-2-группы,-те-кто-ушли-в-отток-и-кто-остался-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравним 2 группы, те кто ушли в отток и кто остался</a></span></li><li><span><a href="#Построим-матрицу-корреляций-и-отобразим-её" data-toc-modified-id="Построим-матрицу-корреляций-и-отобразим-её-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Построим матрицу корреляций и отобразим её</a></span></li><li><span><a href="#Промежуточный-вывод-по-блоку" data-toc-modified-id="Промежуточный-вывод-по-блоку-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Промежуточный вывод по блоку</a></span></li></ul></li><li><span><a href="#Пострим-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Пострим-модель-прогнозирования-оттока-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Пострим модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Разобьем-данные-на-обучающую-и-валидационную-выборку" data-toc-modified-id="Разобьем-данные-на-обучающую-и-валидационную-выборку-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Разобьем данные на обучающую и валидационную выборку</a></span></li><li><span><a href="#Обучим-модель-на-train-выборке-логистической-регрессией" data-toc-modified-id="Обучим-модель-на-train-выборке-логистической-регрессией-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучим модель на train-выборке логистической регрессией</a></span></li><li><span><a href="#Обучим-модель-на-train-выборке-случайным-лесом" data-toc-modified-id="Обучим-модель-на-train-выборке-случайным-лесом-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Обучим модель на train-выборке случайным лесом</a></span></li><li><span><a href="#Оценим-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке" data-toc-modified-id="Оценим-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке</a></span></li></ul></li><li><span><a href="#Сделаем-кластеризацию-клиентов" data-toc-modified-id="Сделаем-кластеризацию-клиентов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сделаем кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков,-нарисуем-дендрограмму." data-toc-modified-id="Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков,-нарисуем-дендрограмму.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков, нарисуем дендрограмму.</a></span></li><li><span><a href="#Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов" data-toc-modified-id="Обучим-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируем-кластеры-клиентов-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Анализ данных сети фитнес-центров

# %% [markdown]
# Сеть фитнес-центров разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
#
# Проект разработал О.Паньков

# %% [markdown]
# ## Задачи
#
# Чтобы бороться с оттоком, отдел по работе с клиентами  перевёл в электронный вид множество клиентских анкет. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.
#
# * научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# * сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# * проанализировать основные признаки, наиболее сильно влияющие на отток;
# * сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#     * 1) выделить целевые группы клиентов;
#     * 2) предложить меры по снижению оттока;
#     * 3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# Набор данных включает следующие поля:
# Данные клиента за предыдущий до проверки факта оттока месяц:
# * 'gender' — пол;
# * 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
# * 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
# * Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
# * 'Phone' — наличие контактного телефона;
# * 'Age' — возраст;
# * 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# * 'Contract_period' — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
# * 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
# * 'Group_visits' — факт посещения групповых занятий;
# * 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
# * 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
# * 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
# * 'Churn' — факт оттока в текущем месяце.

# %% [markdown]
# ## Загрузка данных

# %%
#загружаем библиотеки
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier,RandomForestRegressor
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score
from scipy.cluster.hierarchy import dendrogram, linkage 
from sklearn.cluster import KMeans
import itertools

sns.set_style('dark')
import warnings
warnings.filterwarnings('ignore')

# %%
try:
    df_gym = pd.read_csv('gym_churn.csv')
except:
    df_gym = pd.read_csv('/datasets/gym_churn.csv')    
df_gym.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
df_gym.shape
# Out:
# (4000, 14)

# %%
df_gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
df_gym[df_gym.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [gender, Near_Location, Partner, Promo_friends, Phone, Contract_period, Group_visits, Age, Avg_additional_charges_total, Month_to_end_contract, Lifetime, Avg_class_frequency_total, Avg_class_frequency_current_month, Churn]
# Index: []

# %% [markdown]
# В датасете 4000 строк 14 колонок. Пропуски отсутсвуют. Все данные представлены в цифровых значениях. Дубликаты отсутсвуют

# %% [markdown]
# ## Исследовательский анализ данных (EDA)

# %% [markdown]
# ### изучим средние значения и стандартные отклонения

# %%
df_gym.describe()
# Out:
#             gender  Near_Location      Partner  Promo_friends        Phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        Contract_period  Group_visits          Age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# Разделение посетителей по полу примерно равное. Почти 85 процентов живут в районе где расположен фитнес-центр. Партнерской программой пользуются 48%, промокод от друзей используют около 30%. Групповые занятия посещали около 40%. Средний лайфтам пользователя приблезительно 4 месяца. Средний отток пользователей на уровне 26%

# %% [markdown]
# ### Сравним 2 группы, те кто ушли в отток и кто остался

# %%
df_gym.groupby('Churn').mean()
# Out:
#          gender  Near_Location   Partner  Promo_friends     Phone  \
# Churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        Contract_period  Group_visits        Age  Avg_additional_charges_total  \
# Churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        Month_to_end_contract  Lifetime  Avg_class_frequency_total  \
# Churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        Avg_class_frequency_current_month
# Churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# По средним значениям видно, что пользователи без партнерской программы уходят чаще, так же заметно что среднее значение количества месяцев абонемента у пользователей в оттоке меньше. Средний возраст пользователей в оттоке меньше, чем у оставшихся. Пользователи в которые ушли меньше пользовались групповыми тренировками.

# %%
df_gym_leave = df_gym.query('Churn == 1')
df_gym_stay = df_gym.query('Churn == 0')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Пол пользователей в 2 группах ')
plt.xlabel('Пол')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Отток среди мужчин и женщин пользователей фитнес-центра примерно равный

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Near_Location', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Пользователи живущие в районе фитнес-центра ')
plt.xlabel('Район')
plt.ylabel('Количество пользователей')
plt.xticks([0, 1], ['нет','да'])
plt.grid()
plt.show;

# %% [markdown]
# Пользователи проживающие не в районе фитнес-центра попадают в отток чаше, но их количество достаточно малое

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Partner', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Пользователи с партнерской программой и без ')
plt.xlabel('Партнерская программа')
plt.ylabel('Количество пользователей')
plt.xticks([0, 1], ['нет','да'])
plt.grid()
plt.show;

# %% [markdown]
# Пользователи без партнерской программы попадают вотток чаще. Партнерская программа имеет хорошую удерживающую способность

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Promo_friends', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Программа "приведи друга" ')
plt.xlabel('Программа "приведи друга"')
plt.ylabel('Количество пользователей')
plt.xticks([0, 1], ['нет','да'])
plt.grid()
plt.show;

# %% [markdown]
# Отток пользователей с программой "приведи друга" ниже.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Phone', hue='Churn',data=df_gym )
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Указание телефонного номера ')
plt.xlabel('Наличие номера телефона')
plt.ylabel('Количество пользователей')
plt.xticks([0, 1], ['нет','да'])
plt.grid()
plt.show;

# %% [markdown]
# Малая доля пользователей не оставила свой номер телефона

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Contract_period', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Длительность абонемента')
plt.xlabel('Длительность абонемента')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Самый активный отток наблюдается у пользователей с абонементом на 1 месяц

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Group_visits', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Посещение групповых занятий')
plt.xlabel('Групповые занятия')
plt.ylabel('Количество пользователей')
plt.xticks([0, 1], ['нет','да'])
plt.grid()
plt.show;

# %% [markdown]
# Пользователи не посещаюшие групповые занятия попадают в отток чаще

# %%
plt.figure(figsize=(10, 6))
x1 = df_gym_leave['Age']
x2 = df_gym_stay['Age']
plt.axvline(df_gym['Age'].mean(), color='red')
plt.hist([x1, x2],bins=40)
plt.legend(['Среднее', 'Ушли', 'Остались'], title='Отток')
plt.title('Возраст пользователей в 2 группах ')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Средний возраст оставшихся пользователей около 29 лет, средний возрасть ушедших пользователей около 26 лет, из графика так же видно, что пик пользователи попадающие в отток моложе средних значений посетителей фитнес-центра

# %%
plt.figure(figsize=(10, 6))
x1 = df_gym_leave['Avg_additional_charges_total']
x2 = df_gym_stay['Avg_additional_charges_total']
plt.axvline(df_gym['Avg_additional_charges_total'].mean(), color='red')
plt.hist([x1, x2],bins=40)
plt.legend(['Среднее', 'Ушли', 'Остались'], title='Отток')
plt.title('Суммарная выручка от других услуг фитнес-центра')
plt.xlabel('Выручка')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Среднее значение суммарной выручки от других услуг фитнес-центра пользователей в оттоке ниже, на графике видно смещение влево от средних значений. Эти пользователи тратят меньше денег на другие услуги центра.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Month_to_end_contract', hue='Churn',data=df_gym)
plt.legend(['Остались', 'Ушли'],title='Отток')
plt.title('Срок до окончания текущего действующего абонемента')
plt.xlabel('Месяцы')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Отток пользователей с остатком абонемента 1 месяц самый большой

# %%
plt.figure(figsize=(10, 6))
x1 = df_gym_leave['Lifetime']
x2 = df_gym_stay['Lifetime']
plt.axvline(df_gym['Lifetime'].mean(), color='red')
plt.hist([x1, x2],bins=40)
plt.legend(['Среднее', 'Ушли', 'Остались'], title='Отток')
plt.title('Лайфтайм пользователей в 2 группах ')
plt.xlabel('Лайфтайм в месяцах')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Лайфтайм пользователей попавших в отток значительно ниже среднего значения

# %%
plt.figure(figsize=(10, 6))
x1 = df_gym_leave['Avg_class_frequency_current_month']
x2 = df_gym_stay['Avg_class_frequency_current_month']
plt.axvline(df_gym['Avg_class_frequency_current_month'].mean(), color='red')
plt.hist([x1, x2],bins=40)
plt.legend(['Среднее', 'Ушли', 'Остались'], title='Отток')
plt.title('Cредняя частота посещений в неделю за предыдущий месяц ')
plt.xlabel('Частота в днях')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Пользователи попавшие в отток мало посещали фитнес-центр в предшествующий месяц, больше всего пользователей совсем не посещали центр в последний месяц

# %%
plt.figure(figsize=(10, 6))
x1 = df_gym_leave['Avg_class_frequency_total']
x2 = df_gym_stay['Avg_class_frequency_total']
plt.axvline(df_gym['Avg_class_frequency_total'].mean(), color='red')
plt.hist([x1, x2],bins=40)
plt.legend(['Среднее', 'Ушли', 'Остались'], title='Отток')
plt.title('Средняя частота посещений в неделю за все время с начала действия абонемента')
plt.xlabel('Частота в днях')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show;

# %% [markdown]
# Как видно из графика пользователи попавшие в отток в среднем реже посещали фитнес-центр в период действия абонемента

# %% [markdown]
# ### Построим матрицу корреляций и отобразим её

# %%
#построим и отрисуем матрицу корреляций
cm = df_gym.corr() #вычисляем матрицу корреляций

# %%
#нарисуем тепловую карту с подписями для матрицы корреляций
plt.figure(figsize=(13, 10))
sns.heatmap(cm, annot=True, square=True, cmap= 'coolwarm', linewidths=1, linecolor='black') #ваш код здесь
plt.show()

# %% [markdown]
# На тепловой карте прослеживается корреляция в числовых переменных. Количество месяцев до окончания абонемента - период абонемента. Частота посщений на протяжении всего абонементе - частота посещения в последний месяц.

# %% [markdown]
# ### Промежуточный вывод по блоку

# %% [markdown]
# * Разделение посетителей по полу примерно равное. Почти 85 процентов живут в районе где расположен фитнес-центр. Партнерской программой пользуются 48%, промокод от друзей используют около 30%. Групповые занятия посещали около 40%. Средний лайфтам пользователя приблезительно 4 месяца. Средний отток пользователей на уровне 26%
# * Отток среди мужчин и женщин пользователей фитнес-центра примерно равный
# * Пользователи проживающие не в районе фитнес-центра попадают в отток чаше, но их количество достаточно малое
# * Пользователи без партнерской программы попадают вотток чаще. Партнерская программа имеет хорошую удерживающую способность
# * Отток пользователей с программой "приведи друга" ниже.
# * Малая доля пользователей не оставила свой номер телефона
# * Самый активный отток наблюдается у пользователей с абонементом на 1 месяц
# * Пользователи не посещаюшие групповые занятия попадают в отток чаще
# * Средний возраст оставшихся пользователей около 29 лет, средний возрасть ушедших пользователей около 26 лет, из графика так же видно, что пик пользователи попадающие в отток моложе средних значений посетителей фитнес-центра
# * Среднее значение суммарной выручки от других услуг фитнес-центра пользователей в оттоке ниже, на графике видно смещение влево от средних значений. Эти пользователи тратят меньше денег на другие услуги центра.
# * Отток пользователей с остатком абонемента 1 месяц самый большой
# * Лайфтайм пользователей попавших в отток значительно ниже среднего значения
# * Пользователи попавшие в отток мало посещали фитнес-центр в предшествующий месяц, больше всего пользователей совсем не посещали центр в последний месяц
# * Как видно из графика пользователи попавшие в отток в среднем реже посещали фитнес-центр в период действия абонемента
# * На тепловой карте прослеживается корреляция в числовых переменных. Количество месяцев до окончания абонемента - период абонемента. Частота посщений на протяжении всего абонементе - частота посещения в последний месяц.

# %% [markdown]
# ## Пострим модель прогнозирования оттока клиентов

# %% [markdown]
# Построим модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце

# %% [markdown]
# ### Разобьем данные на обучающую и валидационную выборку

# %%
# разделяем данные на признаки (матрица X) и целевую переменную (y)
X = df_gym.drop('Churn', axis = 1)
y = df_gym['Churn']
# разделяем модель на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# определим функцию, которая будет выводить наши метрики
def print_all_metrics(y_true, y_pred, y_proba, title='Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    print('\tROC_AUC: {:.2f}'.format(roc_auc_score(y_true, y_proba)))

# %%
# обучите StandartScaler на обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)

# Преобразуйте обучающий и валидационные наборы данных (стандартизируем)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# ### Обучим модель на train-выборке логистической регрессией

# %%
# задайте алгоритм для нашей модели
model_LR = LogisticRegression(solver='liblinear', random_state=0) 

# обучите модель
model_LR.fit(X_train_st, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %% [markdown]
# ### Обучим модель на train-выборке случайным лесом

# %%
# зададим алгоритм для новой модели на основе алгоритма случайного леса
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) # Ваш код здесь
# обучим модель случайного леса
rf_model.fit(X_train_st, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ### Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке

# %%
#Accuracy - доля правильных ответов алгоритма
#Precision - точность
#Recall - полнота
#F-мера достигает максимума при полноте и точности, равными единице
#ROC_AUC - площадь (Area Under Curve) под кривой ошибок (Receiver Operating Characteristic curve ) (Одним из способов оценить модель в целом, не привязываясь к конкретному порогу)

# воспользумся уже обученной моделью, чтобы сделать прогнозы
lr_predictions = model_LR.predict(X_test_st) 
lr_probabilities = model_LR.predict_proba(X_test_st)[:,1]

# выведем все метрики логистической регрессии
print_all_metrics(
    y_test,
    lr_predictions,
    lr_probabilities,
    title='Метрики для модели логистической регрессии:',
)
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.92
# 	Precision: 0.85
# 	Recall: 0.83
# 	F1: 0.84
# 	ROC_AUC: 0.97

# %%
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
rf_predictions = rf_model.predict(X_test_st)# Ваш код здесь
rf_probabilities = rf_model.predict_proba(X_test_st)[:, 1]# Ваш код здесь
# выведем все метрики алгоритма случайного леса
print_all_metrics(y_test, 
                  rf_predictions, 
                  rf_probabilities, 
    title='Метрики для модели случайного леса:'
)
# Out:
# Метрики для модели случайного леса:
# 	Accuracy: 0.92
# 	Precision: 0.84
# 	Recall: 0.81
# 	F1: 0.83
# 	ROC_AUC: 0.97

# %% [markdown]
# Обе модели выглядят не плохо, модель логистической регрессии показала себя чуть лучше

# %% [markdown]
# ## Сделаем кластеризацию клиентов
# Отложим в сторону столбец с оттоком и проведем кластеризацию объектов

# %% [markdown]
# ### Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков, нарисуем дендрограмму.

# %%
# обязательная стандартизация данных перед работой с алгоритмами
X_sc = scaler.fit_transform(X)

linked = linkage(X_sc, method = 'ward') 

plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Hierarchial clustering for GYM')
plt.show()

# %% [markdown]
# Предложенное оптимальное число кластеров 4 — четыре разных цвета на графике

# %% [markdown]
# ### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов

# %%
xx_sc = scaler.fit_transform(X)
km = KMeans(n_clusters=5, random_state=0) # задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
labels = km.fit_predict(xx_sc) # применяем алгоритм к данным и формируем вектор кластеров 
# сохраняем метки кластера в поле нашего датасета
df_gym_cluster = df_gym
df_gym_cluster['cluster_km'] = labels

# выводим статистику по средним значениям наших признаков по кластеру
df_gym_cluster.groupby('cluster_km').mean()
# Out:
#               gender  Near_Location   Partner  Promo_friends     Phone  \
# cluster_km
# 0           0.502970       0.959406  0.783168       0.574257  1.000000
# 1           0.522078       0.862338  0.470130       0.306494  0.000000
# 2           0.495050       0.000000  0.463366       0.079208  1.000000
# 3           0.485737       1.000000  0.350238       0.240095  1.000000
# 4           0.559666       0.976134  0.356802       0.230310  0.998807
#
#             Contract_period  Group_visits        Age  \
# cluster_km
# 0                 10.889109      0.542574  29.982178
# 1                  4.787013      0.425974  29.301299
# 2                  2.352475      0.215842  28.477228
# 3                  1.948494      0.341521  28.167987
# 4                  2.669451      0.473747  30.125298
#
#             Avg_additional_charges_total  Month_to_end_contract  Lifetime  \
# cluster_km
# 0                             160.761016               9.954455  4.736634
# ...

# %%
cluster_features = df_gym_cluster.groupby('cluster_km').mean().reset_index()
numeric_columns = cluster_features.drop(columns=['cluster_km']).columns
cluster_features.style.format({i: '{:.2f}' for i in numeric_columns}) \
    .highlight_max(color='yellowgreen', subset=numeric_columns) \
    .highlight_min(color='coral', subset=numeric_columns)
# Out:
# <style  type="text/css" >
# #T_df431_row0_col3,#T_df431_row0_col4,#T_df431_row0_col5,#T_df431_row0_col6,#T_df431_row0_col7,#T_df431_row0_col10,#T_df431_row2_col5,#T_df431_row3_col2,#T_df431_row3_col5,#T_df431_row3_col14,#T_df431_row4_col1,#T_df431_row4_col8,#T_df431_row4_col9,#T_df431_row4_col11,#T_df431_row4_col12,#T_df431_row4_col13{
#             background-color:  yellowgreen;
#         }#T_df431_row0_col14,#T_df431_row1_col5,#T_df431_row2_col2,#T_df431_row2_col4,#T_df431_row2_col7,#T_df431_row3_col1,#T_df431_row3_col3,#T_df431_row3_col6,#T_df431_row3_col8,#T_df431_row3_col9,#T_df431_row3_col10,#T_df431_row3_col11,#T_df431_row3_col12,#T_df431_row3_col13{
#             background-color:  coral;
# ...

# %% [markdown]
# Анализ кластеров. Описание
# * 0 кластер - большинство живут на районе, пользуются партнерской программой , промо программой "пригласи друга",посещают групповые тренировки, имеют самые длительные абонементы, высокий лайфтайм, низкий отток.
#
# * 1 кластер - проживают на районе, среднее пользование партнерскими программами, не оставляют номер телефона, в среднем абонемент на 4 месяца и остаток по абонементам такой же, лайфтайм выше среднего, по отношению с другими кластерами. не высокий отток.
# * 2 кластер - не проживают на районе,среднее пользование партнерской программой, низкое пользование промо программой "пригласи друга", меньше всех посещают групповые тренировки, имеют достаточно высокий отток.
# * 3 кластер - все проживают на районе,низкое пользование партнерскими программами, ниже среднего пользование промо программой "пригласи друга", низкий размер абонемента, слабо посещают групповые тренировки, короткое количество месяцем остатка абонемента, самый низкий лайфтайм, низкая частота посещения, самый высокий уровень оттока.
# * 4 кластер - большинство живут на районе, низкое пользование партнерскими программами, ниже среднего пользование промо программой "пригласи друга", выше среднего уровень посещения группы. самый высокий лайфтайм, практический самый низкий уровень оттока.

# %% [markdown]
# Посмотрим на средние значения признаков для кластеров:
# * присутсвует разница в среднем возрасте по кластерам
# * присутсвует сильный разброс по сроку абонемента по кластерам
# * присутсвуют 2 кластера с большей долей оттока. Кластер 2 и кластер 3
# * чем больше осталось месяцев по абонементу тем меньше виден отток

# %%
# разделим датафрейм на 2 части, с категориальными признаками и количественными
df_gym_cluster_cat =df_gym_cluster.loc[:,['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone','Contract_period', 'Group_visits', 'Churn', 'cluster_km']]
df_gym_cluster_num = df_gym_cluster.loc[:,['Age','Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime','Avg_class_frequency_total', 'Avg_class_frequency_current_month','cluster_km']]

# %%
def plot_cat_features(df, cluster_col):
    # Создаем список категориальных  признаков
    cat_cols = df.columns.tolist()
   
    
    # Создаем subplot с графиками распределения категориальных признаков
    fig, axes = plt.subplots(nrows=len(cat_cols), ncols=1, figsize=(10, 20))
    for i, col in enumerate(cat_cols):
        sns.countplot(x=col, data=df, hue=cluster_col, ax=axes[i])
        axes[i].set_xlabel('')
        axes[i].set_ylabel(col)
        axes[i].legend(title='Cluster')
        
    plt.tight_layout()
    plt.show() 
    
plot_cat_features(df_gym_cluster_cat, 'cluster_km')

# %%
def plot_num_features(df, cluster_col):
    # Создаем список числовых признаков
    num_cols = df.columns.tolist()
    
    # Создаем subplot с графиками распределения числовых признаков
    fig, axes = plt.subplots(nrows=len(num_cols), ncols=1, figsize=(10, 20))
    for i, col in enumerate(num_cols):
        sns.histplot(data=df, x=col, hue=cluster_col, ax=axes[i])
        axes[i].set_xlabel(col)
        axes[i].set_ylabel('Count')
       
    
    plt.tight_layout()
    plt.show()

plot_num_features(df_gym_cluster_num, 'cluster_km')

# %% [markdown]
# ## Выводы

# %% [markdown]
# Выводы по блоку "Загрузка данных"
# * В датасете 4000 строк 14 колонок. Пропуски отсутсвуют. Все данные представлены в цифровых значениях. Дубликаты отсутсвуют
#
# Выводы по блоку "Исследовательский анализ данных (EDA)"
# * Разделение посетителей по полу примерно равное. Почти 85 процентов живут в районе где расположен фитнес-центр. Партнерской программой пользуются 48%, промокод от друзей используют около 30%. Групповые занятия посещали около 40%. Средний лайфтам пользователя приблезительно 4 месяца. Средний отток пользователей на уровне 26%
# * Отток среди мужчин и женщин пользователей фитнес-центра примерно равный
# * Пользователи проживающие не в районе фитнес-центра попадают в отток чаше, но их количество достаточно малое
# * Пользователи без партнерской программы попадают вотток чаще. Партнерская программа имеет хорошую удерживающую способность
# * Отток пользователей с программой "приведи друга" ниже.
# * Малая доля пользователей не оставила свой номер телефона
# * Самый активный отток наблюдается у пользователей с абонементом на 1 месяц
# * Пользователи не посещаюшие групповые занятия попадают в отток чаще
# * Средний возраст оставшихся пользователей около 29 лет, средний возрасть ушедших пользователей около 26 лет, из графика так же видно, что пик пользователи попадающие в отток моложе средних значений посетителей фитнес-центра
# * Среднее значение суммарной выручки от других услуг фитнес-центра пользователей в оттоке ниже, на графике видно смещение влево от средних значений. Эти пользователи тратят меньше денег на другие услуги центра.
# * Отток пользователей с остатком абонемента 1 месяц самый большой
# * Лайфтайм пользователей попавших в отток значительно ниже среднего значения
# * Пользователи попавшие в отток мало посещали фитнес-центр в предшествующий месяц, больше всего пользователей совсем не посещали центр в последний месяц
# * Как видно из графика пользователи попавшие в отток в среднем реже посещали фитнес-центр в период действия абонемента
# * На тепловой карте прослеживается корреляция в числовых переменных. Количество месяцев до окончания абонемента - период абонемента. Частота посщений на протяжении всего абонементе - частота посещения в последний месяц.
#
# Выводы по блоку "Построение модели прогнозирования оттока клиентов"
# * Обе модели выглядят не плохо, модель логистической регрессии показала себя чуть лучше
#
# Выводы по блоку "Кластеризация клиентов"
# * Предложенное оптимальное число кластеров 4 — четыре разных цвета на графике
# * Посмотрим на средние значения признаков для кластеров:
#     * присутсвует разница в среднем возрасте по кластерам
#     * присутсвует сильный разброс по сроку абонемента по кластерам
#     * присутсвуют 2 кластера с большей долей оттока. Кластер 2 и кластер 3
#     * чем больше осталось месяцев по абонементу тем меньше виден отток
#
# Анализ кластеров. Описание
# * 0 кластер - большинство живут на районе, пользуются партнерской программой , промо программой "пригласи друга",посещают групповые тренировки, имеют самые длительные абонементы, высокий лайфтайм, низкий отток.
#
# * 1 кластер - проживают на районе, среднее пользование партнерскими программами, не оставляют номер телефона, в среднем абонемент на 4 месяца и остаток по абонементам такой же, лайфтайм выше среднего, по отношению с другими кластерами. не высокий отток.
# * 2 кластер - не проживают на районе,среднее пользование партнерской программой, низкое пользование промо программой "пригласи друга", меньше всех посещают групповые тренировки, имеют достаточно высокий отток.
# * 3 кластер - все проживают на районе,низкое пользование партнерскими программами, ниже среднего пользование промо программой "пригласи друга", низкий размер абонемента, слабо посещают групповые тренировки, короткое количество месяцем остатка абонемента, самый низкий лайфтайм, низкая частота посещения, самый высокий уровень оттока.
# * 4 кластер - большинство живут на районе, низкое пользование партнерскими программами, ниже среднего пользование промо программой "пригласи друга", выше среднего уровень посещения группы. самый высокий лайфтайм, практический самый низкий уровень оттока.
# * Из графиков видно, что кластеры 2 и 3 дествительно преобладают в оттоке. Так же на отток влияет срок абонемента и возраст ниже среднего
#
# Выводы и рекоммендации:
#
# Для удержания клиентов предлагаю сделать упор на партнерские программы и программу "приведи друга". Так же привлекать пользователей к групповым занятиям. Разработать вариант абонемента например на 4 месяца. Пользователям в последний месяц абонемента, при отсутвии активности пользователя в последний месяц, предлагать уникальные условия по приобретению будущего абонемента. Для более глубокого анализа потребуются дополнительные данные.
